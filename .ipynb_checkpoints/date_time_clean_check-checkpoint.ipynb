# %%
import gls_preprocess_standard_update_v1 as pp
import pandas as pd
import datetime as dt
import time
import datetime

# %%
df = pd.read_csv("data/jobTitle_employment.csv")

# %%
x = pp.gls_preprocess(df.c_employment_job_start, None,None,None,None,None,None)
result = x.gls_date()
# Out:
#                                             date date_modify_1 date_modify_2
# 16                                           NaN    wrong_date
# 202                                          NaN    wrong_date
# 234                         January 2005 &ndash;    wrong_date
# 235                          August 1999 &ndash;    wrong_date
# 237                                 octobre 2011    wrong_date
# 238                          f&eacute;vrier 2010    wrong_date
# 239                                 octobre 2007    wrong_date
# 240                                    juin 2007    wrong_date
# 241                                novembre 2004    wrong_date
# 445                                7/1999&ndash;    wrong_date
# 500                                    2010 - 11    wrong_date
# 501                                    2004 - 10    wrong_date
# 502                                    2010 - 11    wrong_date
# 503                                    2004 - 10    wrong_date
# 534                                          NaN    wrong_date
# 541                                          NaN    wrong_date
# 548                                          NaN    wrong_date
# 779                         El Paso October 1999    wrong_date
# 856                                       8 / 94    wrong_date
# 877                       September 2011 &ndash;    wrong_date
# 885                                August 2003 -    wrong_date
# 918                                          NaN    wrong_date
# 922                                          NaN    wrong_date
# 926                                          NaN    wrong_date
# 946                               август 2012 г.    wrong_date
# 947                                 июль 2011 г.    wrong_date
# 948                                 июль 2010 г.    wrong_date
# 1035                                    notKnown    wrong_date
# 1037                                    notKnown    wrong_date
# 1084                       December 2007 &ndash;    wrong_date
# 1085                       February 2005 &ndash;    wrong_date
# 1117                           July 2010 &ndash;    wrong_date
# 1118                          March 2009 &ndash;    wrong_date
# 1226                                 July 2010 -    wrong_date
# 1227                               August 2007 -    wrong_date
# 1244                             February 2008 -    wrong_date
# 1245                             February 2006 -    wrong_date
# 1253                                         NaN    wrong_date
# 1640                                      008-06    wrong_date
# 1658                                         NaN    wrong_date
# 1858                                   no2010-05    wrong_date
# 1860                                         NaN    wrong_date
# 1926                          April 2005 &ndash;    wrong_date
# 1953                        January 2011 &ndash;    wrong_date
# 2021                         August 2006 &ndash;    wrong_date
# 2023                          March 1999 &ndash;    wrong_date
# 2025                          March 2004 &ndash;    wrong_date
# 2026                          March 2002 &ndash;    wrong_date
# 2121                            May 2011 &ndash;    wrong_date
# 2122                           July 2009 &ndash;    wrong_date
# 2325                                    notKnown    wrong_date
# 2679                                1999 &ndash;    wrong_date
# 2680                                1996 &ndash;    wrong_date
# 2690                            May 2006 &ndash;    wrong_date
# 2691                           June 2003 &ndash;    wrong_date
# 2693                       November 1999 &ndash;    wrong_date
# 2730                                         NaN    wrong_date
# 2868                            May 2011 &ndash;    wrong_date
# 2870                       December 2002 &ndash;    wrong_date
# 2946                                    2002-03-    wrong_date
# 2949                                    2002-03-    wrong_date
# 2975                         August 2007 &ndash;    wrong_date
# 2976                        January 2001 &ndash;    wrong_date
# 2977                       February 1997 &ndash;    wrong_date
# 2978                        October 1994 &ndash;    wrong_date
# 3059                        January 2005 &ndash;    wrong_date
# 3101                                         NaN    wrong_date
# 3102                                         NaN    wrong_date
# 3103                                         NaN    wrong_date
# 3104                                         NaN    wrong_date
# 3106    Privately Held; 1001-5000 employees; Hos    wrong_date
# 3111                                  Jan 2005 -    wrong_date
# 3112                                  Jul 2005 -    wrong_date
# 3114                                   Jun 2001-    wrong_date
# 3234                                    2008-010    wrong_date
# 3242                                . March 2007    wrong_date
# 3384                             December 2011 -    wrong_date
# 3388                                         NaN    wrong_date
# 3599                                         NaN    wrong_date
# 3672                           July 2009 &ndash;    wrong_date
# 3673                           July 2005 &ndash;    wrong_date
# 3674                           July 2003 &ndash;    wrong_date
# 3696                                         NaN    wrong_date
# 3698                        January 2008 &ndash;    wrong_date
# 3700                         August 2000 &ndash;    wrong_date
# 3868                        October 2003 &ndash;    wrong_date
# 3870                           June 2000 &ndash;    wrong_date
# 3876                         August 2005 &ndash;    wrong_date
# 3877                         August 2004 &ndash;    wrong_date
# 3892                          April 2011 &ndash;    wrong_date
# 3893                           July 2010 &ndash;    wrong_date
# 3922                                         NaN    wrong_date
# 3946                                2004 &ndash;    wrong_date
# 3950                       November 2006 &ndash;    wrong_date
# 3952                        January 1999 &ndash;    wrong_date
# 3954                        January 1996 &ndash;    wrong_date
# 3961                                   Currently    wrong_date
# 3965                                      1997 -    wrong_date
# 3972                                2005 &ndash;    wrong_date
# 3973                                2006 &ndash;    wrong_date
# 4025                         August 2011 &ndash;    wrong_date
# 4026                          March 2009 &ndash;    wrong_date
# 4027                          March 2007 &ndash;    wrong_date
# 4029                                2000 &ndash;    wrong_date
# 4032                         August 2011 &ndash;    wrong_date
# 4033                          March 2009 &ndash;    wrong_date
# 4034                          March 2007 &ndash;    wrong_date
# 4036                                2000 &ndash;    wrong_date
# 4113                      September 2004 &ndash;    wrong_date
# 4146                          March 1988 &ndash;    wrong_date
# 4158                                   Nov. 2007    wrong_date
# 4159                                   Nov. 2008    wrong_date
# 4160                                   Oct. 2005    wrong_date
# 4161                                   Feb. 2005    wrong_date
# 4162                                   Jan. 2004    wrong_date
# 4266                                    notKnown    wrong_date
# 4269                                    notKnown    wrong_date
# 4526                                April 2000 q    wrong_date
# 4529                                April 2000 q    wrong_date
# 4532                                April 2000 q    wrong_date
# 4535                                April 2000 q    wrong_date
# 4626                        October 2006 &ndash;    wrong_date
# 4787                                     unknown    wrong_date
# 4830                                         NaN    wrong_date
# 4831                                         NaN    wrong_date
# 4832                                         NaN    wrong_date
# 4852                          March 2010 &ndash;    wrong_date
# 4894                                Scrum Master    wrong_date
# 4977                                     Nov. 04    wrong_date
# 4979                                     Dec. 02    wrong_date
# 4981                                         NaN    wrong_date
# 5061                                         NaN    wrong_date
# 5118                       December 2009 &ndash;    wrong_date
# 5119                        January 2002 &ndash;    wrong_date
# 5148                                1986 &ndash;    wrong_date
# 5296                                    22004-05    wrong_date
# 5316                                         NaN    wrong_date
# 5344                                       2012-    wrong_date
# 5350                                       1997-    wrong_date
# 5374                                    notKnown    wrong_date
# 5761                           July 2010 &ndash;    wrong_date
# 5777                          April 2011 &ndash;    wrong_date
# 5778                        October 2008 &ndash;    wrong_date
# 5779                       February 2008 &ndash;    wrong_date
# 5780                        January 2006 &ndash;    wrong_date
# 5781                          March 2004 &ndash;    wrong_date
# 5782                          April 2011 &ndash;    wrong_date
# 5783                        October 2008 &ndash;    wrong_date
# 5784                       February 2008 &ndash;    wrong_date
# 5785                        January 2006 &ndash;    wrong_date
# 5786                          March 2004 &ndash;    wrong_date
# 5797                        October 2005 &ndash;    wrong_date
# 5942                                         NaN    wrong_date
# 6095                       February 2008 &ndash;    wrong_date
# 6105                                   Currently    wrong_date
# 6278                                  Sept. 2005    wrong_date
# 6279                                August  2001    wrong_date
# 6460                                   Currently    wrong_date
# 6482                                   Currently    wrong_date
# 6591                          April 2008 &ndash;    wrong_date
# 6638                                March 2009 -    wrong_date
# 6639                               August 2007 -    wrong_date
# 6640                            September 2005 -    wrong_date
# 6694                                 April, 2009    wrong_date
# 6695                             September, 2005    wrong_date
# 6696                                 March, 2001    wrong_date
# 6697                                  June, 2000    wrong_date
# 6698                                  Sept, 1997    wrong_date
# 6702                               August 2010 -    wrong_date
# 6705                                April 2008 -    wrong_date
# 6709                               August 2010 -    wrong_date
# 6712                                April 2008 -    wrong_date
# 6768                                   Currently    wrong_date
# 6794                                 June 2009 -    wrong_date
# 6808                              October 2005 -    wrong_date
# 6823                                 July 2010 -    wrong_date
# 6824                                 July 2008 -    wrong_date
# 6829                                  May 2010 -    wrong_date
# 6831                 January 2007 - October 2009    wrong_date
# 6832                            September 2004 -    wrong_date
# 6855                           June 2009 &ndash;    wrong_date
# 7103                                         NaN    wrong_date
# 7294                          April 2005 &ndash;    wrong_date
# 7388                                         NaN    wrong_date
# 7482                                    notKnown    wrong_date
# 7602                                    notKnown    wrong_date
# 7603                                    notKnown    wrong_date
# 7691                       December 2011 &ndash;    wrong_date
# 7693                                      2008 -    wrong_date
# 7694                                      2004 -    wrong_date
# 7782                                         NaN    wrong_date
# 7807                           June 2007 &ndash;    wrong_date
# 7971                                    notKnown    wrong_date
# 8023                                         NaN    wrong_date
# 8097                       February 2005 &ndash;    wrong_date
# 8139                           June 2009 &ndash;    wrong_date
# 8327                                         NaN    wrong_date
# 8356                       February 2010 &ndash;    wrong_date
# 8727                                   Mar. 2006    wrong_date
# 8829                                    notKnown    wrong_date
# 8831                                    notKnown    wrong_date
# 8833                                    notKnown    wrong_date
# 8835                                    notKnown    wrong_date
# 8837                                    notKnown    wrong_date
# 8887                       December 2006 &ndash;    wrong_date
# 9010                              septembre 2008    wrong_date
# 9011                         f&eacute;vrier 2008    wrong_date
# 9012                                   mars 2007    wrong_date
# 9013                                janvier 2005    wrong_date
# 9079                                   Apri 2011    wrong_date
# 9093                                         NaN    wrong_date
# 9096                                         NaN    wrong_date
# 9164                        January 2010 &ndash;    wrong_date
# 9167                        January 2010 &ndash;    wrong_date
# 9306                        January 2010 &ndash;    wrong_date
# 9308                           July 2002 &ndash;    wrong_date
# 9309                      September 1993 &ndash;    wrong_date
# 9314                                      199709    wrong_date
# 9386                           June 2011 &ndash;    wrong_date
# 9438                                confidential    wrong_date
# 9546                                    2011--01    wrong_date
# 9557                                   Currently    wrong_date
# 9558                                   Currently    wrong_date
# 9559                                   Currently    wrong_date
# 9560                                   Currently    wrong_date
# 9566                                   Currently    wrong_date
# 9575                                   Currently    wrong_date
# 9584                                   Currently    wrong_date
# 9585                                   Currently    wrong_date
# 9586                                   Currently    wrong_date
# 9592                                   Currently    wrong_date
# 9792    Privately Held; 201-500 employees; Inter    wrong_date
# 9793                       November 2010 &ndash;    wrong_date
# 9794                                2009 &ndash;    wrong_date
# 10013                                   2005/10-    wrong_date
# 10022                                    Jan2007    wrong_date
# 10024                                    Dec2004    wrong_date
# 10026                                    Nov2000    wrong_date
# 10179                                        NaN    wrong_date
# 10189                                        NaN    wrong_date
# 10195                                        NaN    wrong_date
# 10344                        August 2008 &ndash;    wrong_date
# 10444                       January 2006 &ndash;    wrong_date
# 10491                                        NaN    wrong_date
# 10634                                        NaN    wrong_date
# 10827                       October 2007 &ndash;    wrong_date
# 10830                       October 2007 &ndash;    wrong_date
# 10843                                        Jan    wrong_date
# 11297                                        NaN    wrong_date
# 11414                         March 2008 &ndash;    wrong_date
# 11493                               1998 &ndash;    wrong_date
# 11596                        August 2004 &ndash;    wrong_date
# 11599                                   20012-08    wrong_date
# 11645                                   notKnown    wrong_date
# 11652                          july 2010 &ndash;    wrong_date
# 11695                                        NaN    wrong_date
# 11894                                        NaN    wrong_date
# 11941                                   Ifigenia    wrong_date
# 11947                                   Ifigenia    wrong_date
# 11953                                   Ifigenia    wrong_date
# 11959                                   Ifigenia    wrong_date
# 12106                                   notKnown    wrong_date
# 12370                                  2010-2012    wrong_date
# 12622                                    Apr2002    wrong_date
# 12672                     September 2008 &ndash;    wrong_date
# 12723                                     Oracle    wrong_date
# 12823                          June 2008 &ndash;    wrong_date
# 12824                       October 2007 &ndash;    wrong_date
# 12825                          June 2007 &ndash;    wrong_date
# 12826                           Nov 2006 &ndash;    wrong_date
# 12827                           May 2006 &ndash;    wrong_date
# 12828                           Feb 2006 &ndash;    wrong_date
# 12829                           Aug 2005 &ndash;    wrong_date
# 12830                           Feb 2005 &ndash;    wrong_date
# 12940                          June 2006 &ndash;    wrong_date
# 12944                          June 2006 &ndash;    wrong_date
# 13046                             Citrix Systems    wrong_date
# 13048                      November 2006 &ndash;    wrong_date
# 13054                       January 2003 &ndash;    wrong_date
# 13080                          July 2004 &ndash;    wrong_date
# 13086                                    Gridsum    wrong_date
# 13087                         April 2010 &ndash;    wrong_date
# 13092                      February 2008 &ndash;    wrong_date
# 13093                       January 2004 &ndash;    wrong_date
# 13096                       October 2010 &ndash;    wrong_date
# 13130                          June 2010 &ndash;    wrong_date
# 13147                          June 2009 &ndash;    wrong_date
# 13148                       October 2008 &ndash;    wrong_date
# 13149                          July 2008 &ndash;    wrong_date
# 13159                                        NaN    wrong_date
# 13259                                  Nov. 2007    wrong_date
# 13262                             February, 2000    wrong_date
# 13263                            September, 1996    wrong_date
# 13265                                  Nov. 2007    wrong_date
# 13268                             February, 2000    wrong_date
# 13269                            September, 1996    wrong_date
# 13317                     September 2000 &ndash;    wrong_date
# 13334                      September 1998&ndash;    wrong_date
# 13422                                        NaN    wrong_date
# 13427                                        NaN    wrong_date
# 13476                                   notKnown    wrong_date
# 13567                                        NaN    wrong_date
# 13658                                     1998 -    wrong_date
# 13714                      November 2001 &ndash;    wrong_date
# 13766                                        NaN    wrong_date
# 13840                                        NaN    wrong_date
# 13994                      November 2010 &ndash;    wrong_date
# 14033                                        NaN    wrong_date
# 14261                                        NaN    wrong_date
# 14265                              Oct ober 2009    wrong_date
# 14450                             Aug&#039; 2005    wrong_date
# 14451                               Jun&rsquo;97    wrong_date
# 14465                          June 1998 &ndash;    wrong_date
# 14474                       October 2010 &ndash;    wrong_date
# 14478                      November 2004 &ndash;    wrong_date
# 14479                         2003-November 2003    wrong_date
# 14485                                        NaN    wrong_date
# 14509                             19January 2007    wrong_date
# 14657                                   notKnown    wrong_date
# 14840                     September 1999 &ndash;    wrong_date
# 15165                                 May 2010 -    wrong_date
# 15172                                 May 2010 -    wrong_date
# 15188                            November 1999 -    wrong_date
# 15197                                        NaN    wrong_date
# 15209                            December 2006 -    wrong_date
# 15333                            December 2010 -    wrong_date
# 15334                                June 2010 -    wrong_date
# 15350                                       E.ON    wrong_date
# 15690                      February 2008 &ndash;    wrong_date
# 15692                      December 2004 &ndash;    wrong_date
# 15697                      February 2008 &ndash;    wrong_date
# 15699                      December 2004 &ndash;    wrong_date
# 15704                      February 2008 &ndash;    wrong_date
# 15706                      December 2004 &ndash;    wrong_date
# 15726                       October 2011 &ndash;    wrong_date
# 15727                         March 2010 &ndash;    wrong_date
# 16018                                   notKnown    wrong_date
# 16038                           May 2009 &ndash;    wrong_date
# 16106                      February 2011 &ndash;    wrong_date
# 16163                                        NaN    wrong_date
# 16170                                        NaN    wrong_date
# 16282                          June 2001 &ndash;    wrong_date
# 16359                            TE Connectivity    wrong_date
# 16405                                  2009 - 05    wrong_date
# 16584                                        NaN    wrong_date
# 16610                      November 2007 &ndash;    wrong_date
# 16622                                      Nokia    wrong_date
# 16625                          July 2007 &ndash;    wrong_date
# 16650                       January 1994 &ndash;    wrong_date
# 16797                      February 1998 &ndash;    wrong_date
# 16799                      February 1998 &ndash;    wrong_date
# 16801                      February 1998 &ndash;    wrong_date
# 16906                                        NaN    wrong_date
# 16914                                        NaN    wrong_date
# 16922                                        NaN    wrong_date
# 16937                          July 2008 &ndash;    wrong_date
# 17009   Head of Acquisition, Strategy &amp; Plan    wrong_date
# 17015                                        NaN    wrong_date
# 17033                        August 2011 &ndash;    wrong_date
# 17125                          July 2008 &ndash;    wrong_date
# 17146                     September 2008 &ndash;    wrong_date
# 17185                                        NaN    wrong_date
# 17204                                        NaN    wrong_date
# 17224                         HSBC December 2011    wrong_date
# 17259                                        NaN    wrong_date
# 17294                                        NaN    wrong_date
# 17393                                        NaN    wrong_date
# 17498                                        NaN    wrong_date
# 17582                                        NaN    wrong_date
# 17695                            February 1996 -    wrong_date
# 17732                            September, 1998    wrong_date
# 17786                                    6/1996-    wrong_date
# 17819                      November 2005 &ndash;    wrong_date
# 17826                          July 2001 &ndash;    wrong_date
# 17831                          July 2001 &ndash;    wrong_date
# 17847                               confidential    wrong_date
# 18038                           September 2007 -    wrong_date
# 18069                                        NaN    wrong_date
# 18076                                July 2003 -    wrong_date
# 18243                                        NaN    wrong_date
# 18246                                        NaN    wrong_date
# 18291                                     1997 –    wrong_date
# 18538                                January 201    wrong_date
# 18584                                          -    wrong_date
# 18610                                June 2001 -    wrong_date
# 18615                             October 2010 -    wrong_date
# 18616                            December 2009 -    wrong_date
# 18634                                     2001 -    wrong_date
# 18860                                    Technip    wrong_date
# 18901                          June 2006 &ndash;    wrong_date
# 19026                                   notKnown    wrong_date
# 19158                                        NaN    wrong_date
# 19258                                    Fujitsu    wrong_date
# 19305                                 June 20066    wrong_date
# 19393                               2000 &ndash;    wrong_date
# 19432                         March 2005 &ndash;    wrong_date
# 19468                         March 2006 &ndash;    wrong_date
# 20017                                   2008- 09    wrong_date
# 20193                                  Schindler    wrong_date
# 20358                                   notKnown    wrong_date
# 20471                                   notKnown    wrong_date
# 20472                                   notKnown    wrong_date
# 20499                       January 2009 &ndash;    wrong_date
# 20705                               2004 &ndash;    wrong_date
# 20715                                ноябрь 2011    wrong_date
# 20716                                  март 2002    wrong_date
# 20783                               2012 &ndash;    wrong_date
# 20834                         March 2008 &ndash;    wrong_date
# 20886                                   notKnown    wrong_date
# 20887                        BAEsystems May 2008    wrong_date
# 20925                            Partner-Partner    wrong_date
# 21187           MS Elevators Engineering Sdn Bhd    wrong_date
# 21413                           May 1996 &ndash;    wrong_date
# 21443                                   uly 2007    wrong_date
# 21467                      December 2009 &ndash;    wrong_date
# 21468                         April 2009 &ndash;    wrong_date
# 21481   Public Company; CSCO; Computer Networkin    wrong_date
# 21622        JJMA Associates, Inc September 2000    wrong_date
# 21937                                        NaN    wrong_date
# 22454                                        NaN    wrong_date
# 22455                                        NaN    wrong_date
# 22456                                        NaN    wrong_date
# 22579   Quality and risk management - QRM Lead S    wrong_date
# 22580                       October 2007 &ndash;    wrong_date
# 22816                      November 2007 &ndash;    wrong_date
# 22820                      November 2007 &ndash;    wrong_date
# 23030                                   notKnown    wrong_date
# 23070                                anuary 2009    wrong_date
# 23102                      Roche Pharmaceuticals    wrong_date
# 23130                                 Sept. 2008    wrong_date
# 23132                                  Aug. 2003    wrong_date
# 23133                                  Oct. 2001    wrong_date
# 23134                                  Dec. 1999    wrong_date
# 23337                               April 2009 –    wrong_date
# 23453                         March 1999 &ndash;    wrong_date
# 23555                                        NaN    wrong_date
# 23629                                  Oct  2010    wrong_date
# 23732                                   notKnown    wrong_date
# 23958                                   notKnown    wrong_date
# 23964   lectronic Frontier Foundation September     wrong_date
# 24122                     Covario September 2008    wrong_date
# 24453                                   notKnown    wrong_date
# 24454                                   notKnown    wrong_date
# 24455                                   notKnown    wrong_date
# 24711                              9/2009-2/2011    wrong_date
# 24727                                   notKnown    wrong_date
# 24728                                   notKnown    wrong_date
# 24729                                   notKnown    wrong_date
# 24779                       January 2005 &ndash;    wrong_date
# 24782                       January 2005 &ndash;    wrong_date
# 24834                                     2000 –    wrong_date
# 24939    February 2009 &ndash;  &ndash; November    wrong_date
# 25148                                      20109    wrong_date
# 25157                                      20109    wrong_date
# 25243                      February 2002 &ndash;    wrong_date
# 25251                               2004 &ndash;    wrong_date
# 25304                       October 2002 &ndash;    wrong_date
# 25308                       October 2002 &ndash;    wrong_date
# 25312                       October 2002 &ndash;    wrong_date
# 25348                          June 2010 &ndash;    wrong_date
# 25349                                        NaN    wrong_date
# 25450                              June2012 2009    wrong_date
# 25513                                         --    wrong_date
# 25603                         April 2004 &ndash;    wrong_date
# 25632                                    October    wrong_date
# 25732                                        NaN    wrong_date
# 25875                        August 2010 &ndash;    wrong_date
# 25902                           Jul 2000 &ndash;    wrong_date
# 25983                         March 2009 &ndash;    wrong_date
# 26215                                   notKnown    wrong_date
# 26230                       January 2005 &ndash;    wrong_date
# 26232                       January 2004 &ndash;    wrong_date
# 26233                       January 1993 &ndash;    wrong_date
# 26271                        August 2011 &ndash;    wrong_date
# 26478                          June 2010 &ndash;    wrong_date
# 26481                          July 2006 &ndash;    wrong_date
# 26482                      November 2003 &ndash;    wrong_date
# 26558                        August 2011 &ndash;    wrong_date
# 26564                         April 2011 &ndash;    wrong_date
# 26693                           May 2007 &ndash;    wrong_date
# 26760                                        NaN    wrong_date
# 26945                     Meddius September 2009    wrong_date
# 27119                                        NaN    wrong_date
# 27444                                June 2009 –    wrong_date
# 27445                             January 2009 –    wrong_date
# 27734                                        NaN    wrong_date
# 27936                                   notKnown    wrong_date
# 27937                                   notKnown    wrong_date
# 28358                                   notKnown    wrong_date
# 28406                          July 2009 &ndash;    wrong_date
# 28506                                        NaN    wrong_date
# 28549                                        NaN    wrong_date
# 28607                                        NaN    wrong_date
# 28623                               2010 &ndash;    wrong_date
# 28630                     September 2007 &ndash;    wrong_date
# 28631                       October 2006 &ndash;    wrong_date
# 28632                          July 2005 &ndash;    wrong_date
# 28634                      November 2003 &ndash;    wrong_date
# 28635                          July 2003 &ndash;    wrong_date
# 28639                               2010 &ndash;    wrong_date
# 28646                     September 2007 &ndash;    wrong_date
# 28647                       October 2006 &ndash;    wrong_date
# 28648                          July 2005 &ndash;    wrong_date
# 28650                      November 2003 &ndash;    wrong_date
# 28651                          July 2003 &ndash;    wrong_date
# 28655                               2010 &ndash;    wrong_date
# 28662                     September 2007 &ndash;    wrong_date
# 28663                       October 2006 &ndash;    wrong_date
# 28664                          July 2005 &ndash;    wrong_date
# 28666                      November 2003 &ndash;    wrong_date
# 28667                          July 2003 &ndash;    wrong_date
# 28780                          July 2009 &ndash;    wrong_date
# 28781                         April 2009 &ndash;    wrong_date
# 28782                      February 2009 &ndash;    wrong_date
# 28784                      November 2008 &ndash;    wrong_date
# 28831                      December 2005 &ndash;    wrong_date
# 28832                       October 2003 &ndash;    wrong_date
# 28901                           Jul 2004 &ndash;    wrong_date
# 28911                           Oct 2011 &ndash;    wrong_date
# 28926                                        NaN    wrong_date
# 29162                     September 2007 &ndash;    wrong_date
# 29388                          June 2004 &ndash;    wrong_date
# 29684                                        NaN    wrong_date
# 29952              Sumitomo Bakelite (S) Pte Ltd    wrong_date
# 29986                             ptSeember 2008    wrong_date
# 30166                                        NaN    wrong_date
# 30766                                        NaN    wrong_date
# 30819                          July 2011 &ndash;    wrong_date
# 30825                       January 2005 &ndash;    wrong_date
# 30829                          July 2011 &ndash;    wrong_date
# 30835                       January 2005 &ndash;    wrong_date
# 30840                                        NaN    wrong_date
# 30935                                        NaN    wrong_date
# 30936                                      2009-    wrong_date
# 30947                      November 2011 &ndash;    wrong_date
# 30948                      November 2007 &ndash;    wrong_date
# 31003         January 1998 &ndash; December 1999    wrong_date
# 31023                                      1/03-    wrong_date
# 31024                                      2/09-    wrong_date
# 31025                                   5/2002 -    wrong_date
# 31027                                     11/08-    wrong_date
# 31036                                June 2007 -    wrong_date
# 31037                             January 2003 -    wrong_date
# 31221                       January 2005 &ndash;    wrong_date
# 31307                         April 2011 &ndash;    wrong_date
# 31308                          June 2010 &ndash;    wrong_date
# 31309                      February 2010 &ndash;    wrong_date
# 31310                      December 2008 &ndash;    wrong_date
# 31312                                 June 20076    wrong_date
# 31400                           Jan 2000 &ndash;    wrong_date
# 31408                         March 2010 &ndash;    wrong_date
# 31410                     September 2003 &ndash;    wrong_date
# 31433                           Feb 2005 &ndash;    wrong_date
# 31479                           May 2009 &ndash;    wrong_date
# 31485                                   notKnown    wrong_date
# 31593                                        207    wrong_date
# 31712                                   notKnown    wrong_date
# 31807                           May 2002 &ndash;    wrong_date
# 31889                                        NaN    wrong_date
# 32029                      December 2011 &ndash;    wrong_date
# 32031                      December 2011 &ndash;    wrong_date
# 32039                              December 00 -    wrong_date
# 32052                                 01/2010 to    wrong_date
# 32058                                 01/2010 to    wrong_date
# 32064                                 01/2010 to    wrong_date
# 32118                                June 2010 -    wrong_date
# 32143                                 1999 2004-    wrong_date
# 32347                                        NaN    wrong_date
# 32376                                         --    wrong_date
# 32428                           Aug 2011 &ndash;    wrong_date
# 32431                           Nov 2005 &ndash;    wrong_date
# 32480                           Apr 2012 &ndash;    wrong_date
# 32481                           Feb 2011 &ndash;    wrong_date
# 32485                           Jan 2007 &ndash;    wrong_date
# 32612                           May 2008 &ndash;    wrong_date
# 32613                           Dec 2006 &ndash;    wrong_date
# 32642                                    Technip    wrong_date
# 32657                          July 2008 &ndash;    wrong_date
# 32680                               2010 &ndash;    wrong_date
# 32705                          June 2011 &ndash;    wrong_date
# 32990                          July 2008 &ndash;    wrong_date
# 33061                             January 2012 -    wrong_date
# 33099                             October 2008 –    wrong_date
# 33101                              August 2007 –    wrong_date
# 33223                                   2009-090    wrong_date
# 33241                           May 2004 &ndash;    wrong_date
# 33242                     September 2001 &ndash;    wrong_date
# 33320                             October 2009 –    wrong_date
# 33321                                 May 2008 –    wrong_date
# 33322                               April 2004 –    wrong_date
# 33324         • Provide sales demos to potential    wrong_date
# 33325                           September 2011 –    wrong_date
# 33367                                 Jun 2007 -    wrong_date
# 33374                                     2009 -    wrong_date
# 33376                                     2008 -    wrong_date
# 33377                                     2007 -    wrong_date
# 33379                                      2005-    wrong_date
# 33381                                      2000-    wrong_date
# 33573                         March 2004 &ndash;    wrong_date
# 33637                       October 2010 &ndash;    wrong_date
# 33638                          June 2010 &ndash;    wrong_date
# 33639                         April 2009 &ndash;    wrong_date
# 34035                                        ---    wrong_date
# 34038                              September 201    wrong_date
# 34484                                    unknown    wrong_date
# 34523                                    unknown    wrong_date
# 34613                                        NaN    wrong_date
# 34623                                     2009 -    wrong_date
# 34624                              &bull; 2008 -    wrong_date
# 34625                                     2007 -    wrong_date
# 34629                                     2009 -    wrong_date
# 34630                              &bull; 2008 -    wrong_date
# 34631                                     2007 -    wrong_date
# 34645                                  Oct. 2001    wrong_date
# 34646                                  Aug. 2000    wrong_date
# 34748                                         --    wrong_date
# 34811                                        NaN    wrong_date
# 34846                                    unknown    wrong_date
# 34877                                   notKnown    wrong_date
# 34878                                    unknown    wrong_date
# 34932                                    unknown    wrong_date
# 35081                           Nov 2004 &ndash;    wrong_date
# ...
# 179577                                       NaN    wrong_date
# 179578                                       NaN    wrong_date
# 179609                                       NaN    wrong_date
# 179907                                     1998-    wrong_date
# 179915                                     1998-    wrong_date
# 180059                                  notKnown    wrong_date
# 180063                                  notKnown    wrong_date
# 180353                               l June 2012    wrong_date
# 180357                               l June 2012    wrong_date
# 180524                                  notKnown    wrong_date
# 180553                                     02009    wrong_date
# 180796                                  notKnown    wrong_date
# 180853                                       NaN    wrong_date
# 181038                                  notKnown    wrong_date
# 181137                             September 201    wrong_date
# 181212                                       NaN    wrong_date
# 181242                                       NaN    wrong_date
# 181263                                       NaN    wrong_date
# 181264                                       NaN    wrong_date
# 181275                                       NaN    wrong_date
# 181722                                       NaN    wrong_date
# 182245                                  June2007    wrong_date
# 182411                                  notKnown    wrong_date
# 182413                                       NaN    wrong_date
# 182526                                       NaN    wrong_date
# 183197                                June, 2004    wrong_date
# 183473                                  2007-025    wrong_date
# 183575                                       NaN    wrong_date
# 183834                                       NaN    wrong_date
# 183949                                  2009-098    wrong_date
# 184108                                Oct 200810    wrong_date
# 184733                                       NaN    wrong_date
# 184735                                       NaN    wrong_date
# 184760                               July 2009 -    wrong_date
# 184762                                May 2004 -    wrong_date
# 184772                                       NaN    wrong_date
# 184774                                       NaN    wrong_date
# 184841                                       NaN    wrong_date
# 185200                                  2011 -02    wrong_date
# 185209                                       NaN    wrong_date
# 185231                                   2006-40    wrong_date
# 185473                                       NaN    wrong_date
# 185568                                  notKnown    wrong_date
# 185570                                       NaN    wrong_date
# 185579                                       NaN    wrong_date
# 185602                                       NaN    wrong_date
# 185609                                   l 01/13    wrong_date
# 185661                                   DEC1999    wrong_date
# 186051                                       NaN    wrong_date
# 186205                                  notKnown    wrong_date
# 186208                                  notKnown    wrong_date
# 186695                                       NaN    wrong_date
# 187063                           September 19988    wrong_date
# 187517                                       NaN    wrong_date
# 187583                                    200812    wrong_date
# 187769                                       NaN    wrong_date
# 187770                                       NaN    wrong_date
# 187771                                       NaN    wrong_date
# 187772                                       NaN    wrong_date
# 187912                                       NaN    wrong_date
# 188107                                       NaN    wrong_date
# 188305                                       NaN    wrong_date
# 188407                                       NaN    wrong_date
# 188647                                  notKnown    wrong_date
# 188648                                  notKnown    wrong_date
# 188649                                  notKnown    wrong_date
# 188650                                  notKnown    wrong_date
# 188878                                July, 2007    wrong_date
# 188879                                 Oct, 2005    wrong_date
# 188920                              December 201    wrong_date
# 189013                             August 2010 -    wrong_date
# 189016                               June 2006 -    wrong_date
# 189074                                 12/2008 -    wrong_date
# 189075                           8/2006 - 7/2007    wrong_date
# 189109                                       NaN    wrong_date
# 189111                                       NaN    wrong_date
# 189114                             August 2008 -    wrong_date
# 189194                                       NaN    wrong_date
# 189206                                 Feb 2012-    wrong_date
# 189208                                July 2010-    wrong_date
# 189209                              March 2009 -    wrong_date
# 189210                                July 2007-    wrong_date
# 189211                                May 2008 -    wrong_date
# 189212                                OCT 2006 -    wrong_date
# 189213                                Aug 2004 -    wrong_date
# 189260                                       NaN    wrong_date
# 189492                                  1 / 2004    wrong_date
# 189592                                       NaN    wrong_date
# 189593                                       NaN    wrong_date
# 189643                                       NaN    wrong_date
# 189692                                       NaN    wrong_date
# 189761                                       NaN    wrong_date
# 189993                                       NaN    wrong_date
# 190227                                Apr 2009 -    wrong_date
# 190424                                       NaN    wrong_date
# 190498                                     2005-    wrong_date
# 190506                                    2011 -    wrong_date
# 190507                               Sept.2010 -    wrong_date
# 190547                                       NaN    wrong_date
# 190591                            , January 2003    wrong_date
# 190592                              July 2005 to    wrong_date
# 190606                                       NaN    wrong_date
# 190657                                       NaN    wrong_date
# 190813                                       NaN    wrong_date
# 190939                          June &ndash;2011    wrong_date
# 190961                                       NaN    wrong_date
# 191142                                  notKnown    wrong_date
# 191246                                       NaN    wrong_date
# 191308                                       NaN    wrong_date
# 191456                                     1998-    wrong_date
# 191486                                       NaN    wrong_date
# 191487                                       NaN    wrong_date
# 191582                                       NaN    wrong_date
# 191603                                       NaN    wrong_date
# 191800                                       NaN    wrong_date
# 192264                                       NaN    wrong_date
# 192368                                  notKnown    wrong_date
# 192513                                       NaN    wrong_date
# 192531                                  notKnown    wrong_date
# 192667                                       NaN    wrong_date
# 192775                                       NaN    wrong_date
# 192787                                       NaN    wrong_date
# 192812                                       NaN    wrong_date
# 192864                                 SAP Basis    wrong_date
# 193082                                  notKnown    wrong_date
# 193457                                       NaN    wrong_date
# 193470                                       NaN    wrong_date
# 193481                                  2005 -07    wrong_date
# 193485                                  2005 -07    wrong_date
# 193565                                  2006 -04    wrong_date
# 193601                                       NaN    wrong_date
# 193741                                  notKnown    wrong_date
# 193743                                  notKnown    wrong_date
# 194010                                       NaN    wrong_date
# 194267                                  2011-011    wrong_date
# 194276                                  2011-011    wrong_date
# 194285                                  2011-011    wrong_date
# 194294                                  2011-011    wrong_date
# 194303                                  2011-011    wrong_date
# 194427                                       NaN    wrong_date
# 194453                          Nov 1996 &ndash;    wrong_date
# 194628                                  notKnown    wrong_date
# 194729                                   Jan. 06    wrong_date
# 194857                                       NaN    wrong_date
# 195179  PWC Consulting / IBM Business Consulting    wrong_date
# 195525                                  notKnown    wrong_date
# 195530                              2000 &ndash;    wrong_date
# 195632                               JULY 2006 -    wrong_date
# 195633                            - APRIL 2006 -    wrong_date
# 195634                          - JANUARY 2006 -    wrong_date
# 195635                           - AUGUST 2005 -    wrong_date
# 195636                              - APRIL 2005    wrong_date
# 195637                            AUGUST 2004 to    wrong_date
# 195638                           - MARCH 2004 to    wrong_date
# 195639                               APR 2003 to    wrong_date
# 195640                             - DEC 2001 to    wrong_date
# 195641                               NOV 2000 to    wrong_date
# 195655                                       NaN    wrong_date
# 195663                                       NaN    wrong_date
# 195671                                       NaN    wrong_date
# 196079                          September 201105    wrong_date
# 196135                                  notKnown    wrong_date
# 196296                                       NaN    wrong_date
# 196624                                       NaN    wrong_date
# 196626                                  notKnown    wrong_date
# 196627                                       NaN    wrong_date
# 196629                                       NaN    wrong_date
# 196685                                       NaN    wrong_date
# 196739                                  notKnown    wrong_date
# 196740                                       NaN    wrong_date
# 197434                                       NaN    wrong_date
# 197435                                       NaN    wrong_date
# 197436                                       NaN    wrong_date
# 197437                                       NaN    wrong_date
# 197438                                       NaN    wrong_date
# 197439                                       NaN    wrong_date
# 197440                                       NaN    wrong_date
# 197441                                       NaN    wrong_date
# 197455                            From 12/2011 -    wrong_date
# 197456                             From 4/2004 -    wrong_date
# 197457                             From 9/1999 -    wrong_date
# 197460                         04/2010 - Present    wrong_date
# 197462                                  notKnown    wrong_date
# 197465                                 08/2001 -    wrong_date
# 197466                                  06//2001    wrong_date
# 197484                                  08/04 to    wrong_date
# 197485                                  09/03 to    wrong_date
# 197486                                  01/03 to    wrong_date
# 197487                                  07/01 to    wrong_date
# 197488                                  05/01 to    wrong_date
# 197489                                  09/00 to    wrong_date
# 197490                                       NaN    wrong_date
# 197558                                       NaN    wrong_date
# 197968                                     2003-    wrong_date
# 197978                            April &#039;11    wrong_date
# 197979                            April &#039;10    wrong_date
# 197980                                        07    wrong_date
# 198416                                  notKnown    wrong_date
# 198420                                       NaN    wrong_date
# 198567                                       NaN    wrong_date
# 198807                                       NaN    wrong_date
# 198829                                       NaN    wrong_date
# 199186                              2000 &ndash;    wrong_date
# 199274                                       NaN    wrong_date
# 199325                                       NaN    wrong_date
# 199550                                  notKnown    wrong_date
# 199870                          Jun 2004 &ndash;    wrong_date

# %%
x = pp.gls_preprocess(df.c_employment_job_end, None,None,None,None,None,None)
result_2 = x.gls_date()

# %%
frames = [result, result_2]
final_result = pd.concat(frames)

# %%
final_result.to_csv('clean_date_result.csv')

# %%
len(final_result)
# Out:
# 400000

# %%
len(final_result[final_result.date_modify_1 == 'wrong_date'])
# Out:
# 5949

# %%
pd.set_option('display.max_rows', len(df))
print(final_result[final_result.date_modify_1 == 'wrong_date'])
# Out:
#                                             date date_modify_1 date_modify_2
# 16                                           NaN    wrong_date
# 202                                          NaN    wrong_date
# 234                         January 2005 &ndash;    wrong_date
# 235                          August 1999 &ndash;    wrong_date
# 237                                 octobre 2011    wrong_date
# 238                          f&eacute;vrier 2010    wrong_date
# 239                                 octobre 2007    wrong_date
# 240                                    juin 2007    wrong_date
# 241                                novembre 2004    wrong_date
# 445                                7/1999&ndash;    wrong_date
# 500                                    2010 - 11    wrong_date
# 501                                    2004 - 10    wrong_date
# 502                                    2010 - 11    wrong_date
# 503                                    2004 - 10    wrong_date
# 534                                          NaN    wrong_date
# 541                                          NaN    wrong_date
# 548                                          NaN    wrong_date
# 779                         El Paso October 1999    wrong_date
# 856                                       8 / 94    wrong_date
# 877                       September 2011 &ndash;    wrong_date
# 885                                August 2003 -    wrong_date
# 918                                          NaN    wrong_date
# 922                                          NaN    wrong_date
# 926                                          NaN    wrong_date
# 946                               август 2012 г.    wrong_date
# 947                                 июль 2011 г.    wrong_date
# 948                                 июль 2010 г.    wrong_date
# 1035                                    notKnown    wrong_date
# 1037                                    notKnown    wrong_date
# 1084                       December 2007 &ndash;    wrong_date
# 1085                       February 2005 &ndash;    wrong_date
# 1117                           July 2010 &ndash;    wrong_date
# 1118                          March 2009 &ndash;    wrong_date
# 1226                                 July 2010 -    wrong_date
# 1227                               August 2007 -    wrong_date
# 1244                             February 2008 -    wrong_date
# 1245                             February 2006 -    wrong_date
# 1253                                         NaN    wrong_date
# 1640                                      008-06    wrong_date
# 1658                                         NaN    wrong_date
# 1858                                   no2010-05    wrong_date
# 1860                                         NaN    wrong_date
# 1926                          April 2005 &ndash;    wrong_date
# 1953                        January 2011 &ndash;    wrong_date
# 2021                         August 2006 &ndash;    wrong_date
# 2023                          March 1999 &ndash;    wrong_date
# 2025                          March 2004 &ndash;    wrong_date
# 2026                          March 2002 &ndash;    wrong_date
# 2121                            May 2011 &ndash;    wrong_date
# 2122                           July 2009 &ndash;    wrong_date
# 2325                                    notKnown    wrong_date
# 2679                                1999 &ndash;    wrong_date
# 2680                                1996 &ndash;    wrong_date
# 2690                            May 2006 &ndash;    wrong_date
# 2691                           June 2003 &ndash;    wrong_date
# 2693                       November 1999 &ndash;    wrong_date
# 2730                                         NaN    wrong_date
# 2868                            May 2011 &ndash;    wrong_date
# 2870                       December 2002 &ndash;    wrong_date
# 2946                                    2002-03-    wrong_date
# 2949                                    2002-03-    wrong_date
# 2975                         August 2007 &ndash;    wrong_date
# 2976                        January 2001 &ndash;    wrong_date
# 2977                       February 1997 &ndash;    wrong_date
# 2978                        October 1994 &ndash;    wrong_date
# 3059                        January 2005 &ndash;    wrong_date
# 3101                                         NaN    wrong_date
# 3102                                         NaN    wrong_date
# 3103                                         NaN    wrong_date
# 3104                                         NaN    wrong_date
# 3106    Privately Held; 1001-5000 employees; Hos    wrong_date
# 3111                                  Jan 2005 -    wrong_date
# 3112                                  Jul 2005 -    wrong_date
# 3114                                   Jun 2001-    wrong_date
# 3234                                    2008-010    wrong_date
# 3242                                . March 2007    wrong_date
# 3384                             December 2011 -    wrong_date
# 3388                                         NaN    wrong_date
# 3599                                         NaN    wrong_date
# 3672                           July 2009 &ndash;    wrong_date
# 3673                           July 2005 &ndash;    wrong_date
# 3674                           July 2003 &ndash;    wrong_date
# 3696                                         NaN    wrong_date
# 3698                        January 2008 &ndash;    wrong_date
# 3700                         August 2000 &ndash;    wrong_date
# 3868                        October 2003 &ndash;    wrong_date
# 3870                           June 2000 &ndash;    wrong_date
# 3876                         August 2005 &ndash;    wrong_date
# 3877                         August 2004 &ndash;    wrong_date
# 3892                          April 2011 &ndash;    wrong_date
# 3893                           July 2010 &ndash;    wrong_date
# 3922                                         NaN    wrong_date
# 3946                                2004 &ndash;    wrong_date
# 3950                       November 2006 &ndash;    wrong_date
# 3952                        January 1999 &ndash;    wrong_date
# 3954                        January 1996 &ndash;    wrong_date
# 3961                                   Currently    wrong_date
# 3965                                      1997 -    wrong_date
# 3972                                2005 &ndash;    wrong_date
# 3973                                2006 &ndash;    wrong_date
# 4025                         August 2011 &ndash;    wrong_date
# 4026                          March 2009 &ndash;    wrong_date
# 4027                          March 2007 &ndash;    wrong_date
# 4029                                2000 &ndash;    wrong_date
# 4032                         August 2011 &ndash;    wrong_date
# 4033                          March 2009 &ndash;    wrong_date
# 4034                          March 2007 &ndash;    wrong_date
# 4036                                2000 &ndash;    wrong_date
# 4113                      September 2004 &ndash;    wrong_date
# 4146                          March 1988 &ndash;    wrong_date
# 4158                                   Nov. 2007    wrong_date
# 4159                                   Nov. 2008    wrong_date
# 4160                                   Oct. 2005    wrong_date
# 4161                                   Feb. 2005    wrong_date
# 4162                                   Jan. 2004    wrong_date
# 4266                                    notKnown    wrong_date
# 4269                                    notKnown    wrong_date
# 4526                                April 2000 q    wrong_date
# 4529                                April 2000 q    wrong_date
# 4532                                April 2000 q    wrong_date
# 4535                                April 2000 q    wrong_date
# 4626                        October 2006 &ndash;    wrong_date
# 4787                                     unknown    wrong_date
# 4830                                         NaN    wrong_date
# 4831                                         NaN    wrong_date
# 4832                                         NaN    wrong_date
# 4852                          March 2010 &ndash;    wrong_date
# 4894                                Scrum Master    wrong_date
# 4977                                     Nov. 04    wrong_date
# 4979                                     Dec. 02    wrong_date
# 4981                                         NaN    wrong_date
# 5061                                         NaN    wrong_date
# 5118                       December 2009 &ndash;    wrong_date
# 5119                        January 2002 &ndash;    wrong_date
# 5148                                1986 &ndash;    wrong_date
# 5296                                    22004-05    wrong_date
# 5316                                         NaN    wrong_date
# 5344                                       2012-    wrong_date
# 5350                                       1997-    wrong_date
# 5374                                    notKnown    wrong_date
# 5761                           July 2010 &ndash;    wrong_date
# 5777                          April 2011 &ndash;    wrong_date
# 5778                        October 2008 &ndash;    wrong_date
# 5779                       February 2008 &ndash;    wrong_date
# 5780                        January 2006 &ndash;    wrong_date
# 5781                          March 2004 &ndash;    wrong_date
# 5782                          April 2011 &ndash;    wrong_date
# 5783                        October 2008 &ndash;    wrong_date
# 5784                       February 2008 &ndash;    wrong_date
# 5785                        January 2006 &ndash;    wrong_date
# 5786                          March 2004 &ndash;    wrong_date
# 5797                        October 2005 &ndash;    wrong_date
# 5942                                         NaN    wrong_date
# 6095                       February 2008 &ndash;    wrong_date
# 6105                                   Currently    wrong_date
# 6278                                  Sept. 2005    wrong_date
# 6279                                August  2001    wrong_date
# 6460                                   Currently    wrong_date
# 6482                                   Currently    wrong_date
# 6591                          April 2008 &ndash;    wrong_date
# 6638                                March 2009 -    wrong_date
# 6639                               August 2007 -    wrong_date
# 6640                            September 2005 -    wrong_date
# 6694                                 April, 2009    wrong_date
# 6695                             September, 2005    wrong_date
# 6696                                 March, 2001    wrong_date
# 6697                                  June, 2000    wrong_date
# 6698                                  Sept, 1997    wrong_date
# 6702                               August 2010 -    wrong_date
# 6705                                April 2008 -    wrong_date
# 6709                               August 2010 -    wrong_date
# 6712                                April 2008 -    wrong_date
# 6768                                   Currently    wrong_date
# 6794                                 June 2009 -    wrong_date
# 6808                              October 2005 -    wrong_date
# 6823                                 July 2010 -    wrong_date
# 6824                                 July 2008 -    wrong_date
# 6829                                  May 2010 -    wrong_date
# 6831                 January 2007 - October 2009    wrong_date
# 6832                            September 2004 -    wrong_date
# 6855                           June 2009 &ndash;    wrong_date
# 7103                                         NaN    wrong_date
# 7294                          April 2005 &ndash;    wrong_date
# 7388                                         NaN    wrong_date
# 7482                                    notKnown    wrong_date
# 7602                                    notKnown    wrong_date
# 7603                                    notKnown    wrong_date
# 7691                       December 2011 &ndash;    wrong_date
# 7693                                      2008 -    wrong_date
# 7694                                      2004 -    wrong_date
# 7782                                         NaN    wrong_date
# 7807                           June 2007 &ndash;    wrong_date
# 7971                                    notKnown    wrong_date
# 8023                                         NaN    wrong_date
# 8097                       February 2005 &ndash;    wrong_date
# 8139                           June 2009 &ndash;    wrong_date
# 8327                                         NaN    wrong_date
# 8356                       February 2010 &ndash;    wrong_date
# 8727                                   Mar. 2006    wrong_date
# 8829                                    notKnown    wrong_date
# 8831                                    notKnown    wrong_date
# 8833                                    notKnown    wrong_date
# 8835                                    notKnown    wrong_date
# 8837                                    notKnown    wrong_date
# 8887                       December 2006 &ndash;    wrong_date
# 9010                              septembre 2008    wrong_date
# 9011                         f&eacute;vrier 2008    wrong_date
# 9012                                   mars 2007    wrong_date
# 9013                                janvier 2005    wrong_date
# 9079                                   Apri 2011    wrong_date
# 9093                                         NaN    wrong_date
# 9096                                         NaN    wrong_date
# 9164                        January 2010 &ndash;    wrong_date
# 9167                        January 2010 &ndash;    wrong_date
# 9306                        January 2010 &ndash;    wrong_date
# 9308                           July 2002 &ndash;    wrong_date
# 9309                      September 1993 &ndash;    wrong_date
# 9314                                      199709    wrong_date
# 9386                           June 2011 &ndash;    wrong_date
# 9438                                confidential    wrong_date
# 9546                                    2011--01    wrong_date
# 9557                                   Currently    wrong_date
# 9558                                   Currently    wrong_date
# 9559                                   Currently    wrong_date
# 9560                                   Currently    wrong_date
# 9566                                   Currently    wrong_date
# 9575                                   Currently    wrong_date
# 9584                                   Currently    wrong_date
# 9585                                   Currently    wrong_date
# 9586                                   Currently    wrong_date
# 9592                                   Currently    wrong_date
# 9792    Privately Held; 201-500 employees; Inter    wrong_date
# 9793                       November 2010 &ndash;    wrong_date
# 9794                                2009 &ndash;    wrong_date
# 10013                                   2005/10-    wrong_date
# 10022                                    Jan2007    wrong_date
# 10024                                    Dec2004    wrong_date
# 10026                                    Nov2000    wrong_date
# 10179                                        NaN    wrong_date
# 10189                                        NaN    wrong_date
# 10195                                        NaN    wrong_date
# 10344                        August 2008 &ndash;    wrong_date
# 10444                       January 2006 &ndash;    wrong_date
# 10491                                        NaN    wrong_date
# 10634                                        NaN    wrong_date
# 10827                       October 2007 &ndash;    wrong_date
# 10830                       October 2007 &ndash;    wrong_date
# 10843                                        Jan    wrong_date
# 11297                                        NaN    wrong_date
# 11414                         March 2008 &ndash;    wrong_date
# 11493                               1998 &ndash;    wrong_date
# 11596                        August 2004 &ndash;    wrong_date
# 11599                                   20012-08    wrong_date
# 11645                                   notKnown    wrong_date
# 11652                          july 2010 &ndash;    wrong_date
# 11695                                        NaN    wrong_date
# 11894                                        NaN    wrong_date
# 11941                                   Ifigenia    wrong_date
# 11947                                   Ifigenia    wrong_date
# 11953                                   Ifigenia    wrong_date
# 11959                                   Ifigenia    wrong_date
# 12106                                   notKnown    wrong_date
# 12370                                  2010-2012    wrong_date
# 12622                                    Apr2002    wrong_date
# 12672                     September 2008 &ndash;    wrong_date
# 12723                                     Oracle    wrong_date
# 12823                          June 2008 &ndash;    wrong_date
# 12824                       October 2007 &ndash;    wrong_date
# 12825                          June 2007 &ndash;    wrong_date
# 12826                           Nov 2006 &ndash;    wrong_date
# 12827                           May 2006 &ndash;    wrong_date
# 12828                           Feb 2006 &ndash;    wrong_date
# 12829                           Aug 2005 &ndash;    wrong_date
# 12830                           Feb 2005 &ndash;    wrong_date
# 12940                          June 2006 &ndash;    wrong_date
# 12944                          June 2006 &ndash;    wrong_date
# 13046                             Citrix Systems    wrong_date
# 13048                      November 2006 &ndash;    wrong_date
# 13054                       January 2003 &ndash;    wrong_date
# 13080                          July 2004 &ndash;    wrong_date
# 13086                                    Gridsum    wrong_date
# 13087                         April 2010 &ndash;    wrong_date
# 13092                      February 2008 &ndash;    wrong_date
# 13093                       January 2004 &ndash;    wrong_date
# 13096                       October 2010 &ndash;    wrong_date
# 13130                          June 2010 &ndash;    wrong_date
# 13147                          June 2009 &ndash;    wrong_date
# 13148                       October 2008 &ndash;    wrong_date
# 13149                          July 2008 &ndash;    wrong_date
# 13159                                        NaN    wrong_date
# 13259                                  Nov. 2007    wrong_date
# 13262                             February, 2000    wrong_date
# 13263                            September, 1996    wrong_date
# 13265                                  Nov. 2007    wrong_date
# 13268                             February, 2000    wrong_date
# 13269                            September, 1996    wrong_date
# 13317                     September 2000 &ndash;    wrong_date
# 13334                      September 1998&ndash;    wrong_date
# 13422                                        NaN    wrong_date
# 13427                                        NaN    wrong_date
# 13476                                   notKnown    wrong_date
# 13567                                        NaN    wrong_date
# 13658                                     1998 -    wrong_date
# 13714                      November 2001 &ndash;    wrong_date
# 13766                                        NaN    wrong_date
# 13840                                        NaN    wrong_date
# 13994                      November 2010 &ndash;    wrong_date
# 14033                                        NaN    wrong_date
# 14261                                        NaN    wrong_date
# 14265                              Oct ober 2009    wrong_date
# 14450                             Aug&#039; 2005    wrong_date
# 14451                               Jun&rsquo;97    wrong_date
# 14465                          June 1998 &ndash;    wrong_date
# 14474                       October 2010 &ndash;    wrong_date
# 14478                      November 2004 &ndash;    wrong_date
# 14479                         2003-November 2003    wrong_date
# 14485                                        NaN    wrong_date
# 14509                             19January 2007    wrong_date
# 14657                                   notKnown    wrong_date
# 14840                     September 1999 &ndash;    wrong_date
# 15165                                 May 2010 -    wrong_date
# 15172                                 May 2010 -    wrong_date
# 15188                            November 1999 -    wrong_date
# 15197                                        NaN    wrong_date
# 15209                            December 2006 -    wrong_date
# 15333                            December 2010 -    wrong_date
# 15334                                June 2010 -    wrong_date
# 15350                                       E.ON    wrong_date
# 15690                      February 2008 &ndash;    wrong_date
# 15692                      December 2004 &ndash;    wrong_date
# 15697                      February 2008 &ndash;    wrong_date
# 15699                      December 2004 &ndash;    wrong_date
# 15704                      February 2008 &ndash;    wrong_date
# 15706                      December 2004 &ndash;    wrong_date
# 15726                       October 2011 &ndash;    wrong_date
# 15727                         March 2010 &ndash;    wrong_date
# 16018                                   notKnown    wrong_date
# 16038                           May 2009 &ndash;    wrong_date
# 16106                      February 2011 &ndash;    wrong_date
# 16163                                        NaN    wrong_date
# 16170                                        NaN    wrong_date
# 16282                          June 2001 &ndash;    wrong_date
# 16359                            TE Connectivity    wrong_date
# 16405                                  2009 - 05    wrong_date
# 16584                                        NaN    wrong_date
# 16610                      November 2007 &ndash;    wrong_date
# 16622                                      Nokia    wrong_date
# 16625                          July 2007 &ndash;    wrong_date
# 16650                       January 1994 &ndash;    wrong_date
# 16797                      February 1998 &ndash;    wrong_date
# 16799                      February 1998 &ndash;    wrong_date
# 16801                      February 1998 &ndash;    wrong_date
# 16906                                        NaN    wrong_date
# 16914                                        NaN    wrong_date
# 16922                                        NaN    wrong_date
# 16937                          July 2008 &ndash;    wrong_date
# 17009   Head of Acquisition, Strategy &amp; Plan    wrong_date
# 17015                                        NaN    wrong_date
# 17033                        August 2011 &ndash;    wrong_date
# 17125                          July 2008 &ndash;    wrong_date
# 17146                     September 2008 &ndash;    wrong_date
# 17185                                        NaN    wrong_date
# 17204                                        NaN    wrong_date
# 17224                         HSBC December 2011    wrong_date
# 17259                                        NaN    wrong_date
# 17294                                        NaN    wrong_date
# 17393                                        NaN    wrong_date
# 17498                                        NaN    wrong_date
# 17582                                        NaN    wrong_date
# 17695                            February 1996 -    wrong_date
# 17732                            September, 1998    wrong_date
# 17786                                    6/1996-    wrong_date
# 17819                      November 2005 &ndash;    wrong_date
# 17826                          July 2001 &ndash;    wrong_date
# 17831                          July 2001 &ndash;    wrong_date
# 17847                               confidential    wrong_date
# 18038                           September 2007 -    wrong_date
# 18069                                        NaN    wrong_date
# 18076                                July 2003 -    wrong_date
# 18243                                        NaN    wrong_date
# 18246                                        NaN    wrong_date
# 18291                                     1997 –    wrong_date
# 18538                                January 201    wrong_date
# 18584                                          -    wrong_date
# 18610                                June 2001 -    wrong_date
# 18615                             October 2010 -    wrong_date
# 18616                            December 2009 -    wrong_date
# 18634                                     2001 -    wrong_date
# 18860                                    Technip    wrong_date
# 18901                          June 2006 &ndash;    wrong_date
# 19026                                   notKnown    wrong_date
# 19158                                        NaN    wrong_date
# 19258                                    Fujitsu    wrong_date
# 19305                                 June 20066    wrong_date
# 19393                               2000 &ndash;    wrong_date
# 19432                         March 2005 &ndash;    wrong_date
# 19468                         March 2006 &ndash;    wrong_date
# 20017                                   2008- 09    wrong_date
# 20193                                  Schindler    wrong_date
# 20358                                   notKnown    wrong_date
# 20471                                   notKnown    wrong_date
# 20472                                   notKnown    wrong_date
# 20499                       January 2009 &ndash;    wrong_date
# 20705                               2004 &ndash;    wrong_date
# 20715                                ноябрь 2011    wrong_date
# 20716                                  март 2002    wrong_date
# 20783                               2012 &ndash;    wrong_date
# 20834                         March 2008 &ndash;    wrong_date
# 20886                                   notKnown    wrong_date
# 20887                        BAEsystems May 2008    wrong_date
# 20925                            Partner-Partner    wrong_date
# 21187           MS Elevators Engineering Sdn Bhd    wrong_date
# 21413                           May 1996 &ndash;    wrong_date
# 21443                                   uly 2007    wrong_date
# 21467                      December 2009 &ndash;    wrong_date
# 21468                         April 2009 &ndash;    wrong_date
# 21481   Public Company; CSCO; Computer Networkin    wrong_date
# 21622        JJMA Associates, Inc September 2000    wrong_date
# 21937                                        NaN    wrong_date
# 22454                                        NaN    wrong_date
# 22455                                        NaN    wrong_date
# 22456                                        NaN    wrong_date
# 22579   Quality and risk management - QRM Lead S    wrong_date
# 22580                       October 2007 &ndash;    wrong_date
# 22816                      November 2007 &ndash;    wrong_date
# 22820                      November 2007 &ndash;    wrong_date
# 23030                                   notKnown    wrong_date
# 23070                                anuary 2009    wrong_date
# 23102                      Roche Pharmaceuticals    wrong_date
# 23130                                 Sept. 2008    wrong_date
# 23132                                  Aug. 2003    wrong_date
# 23133                                  Oct. 2001    wrong_date
# 23134                                  Dec. 1999    wrong_date
# 23337                               April 2009 –    wrong_date
# 23453                         March 1999 &ndash;    wrong_date
# 23555                                        NaN    wrong_date
# 23629                                  Oct  2010    wrong_date
# 23732                                   notKnown    wrong_date
# 23958                                   notKnown    wrong_date
# 23964   lectronic Frontier Foundation September     wrong_date
# 24122                     Covario September 2008    wrong_date
# 24453                                   notKnown    wrong_date
# 24454                                   notKnown    wrong_date
# 24455                                   notKnown    wrong_date
# 24711                              9/2009-2/2011    wrong_date
# 24727                                   notKnown    wrong_date
# 24728                                   notKnown    wrong_date
# 24729                                   notKnown    wrong_date
# 24779                       January 2005 &ndash;    wrong_date
# 24782                       January 2005 &ndash;    wrong_date
# 24834                                     2000 –    wrong_date
# 24939    February 2009 &ndash;  &ndash; November    wrong_date
# 25148                                      20109    wrong_date
# 25157                                      20109    wrong_date
# 25243                      February 2002 &ndash;    wrong_date
# 25251                               2004 &ndash;    wrong_date
# 25304                       October 2002 &ndash;    wrong_date
# 25308                       October 2002 &ndash;    wrong_date
# 25312                       October 2002 &ndash;    wrong_date
# 25348                          June 2010 &ndash;    wrong_date
# 25349                                        NaN    wrong_date
# 25450                              June2012 2009    wrong_date
# 25513                                         --    wrong_date
# 25603                         April 2004 &ndash;    wrong_date
# 25632                                    October    wrong_date
# 25732                                        NaN    wrong_date
# 25875                        August 2010 &ndash;    wrong_date
# 25902                           Jul 2000 &ndash;    wrong_date
# 25983                         March 2009 &ndash;    wrong_date
# 26215                                   notKnown    wrong_date
# 26230                       January 2005 &ndash;    wrong_date
# 26232                       January 2004 &ndash;    wrong_date
# 26233                       January 1993 &ndash;    wrong_date
# 26271                        August 2011 &ndash;    wrong_date
# 26478                          June 2010 &ndash;    wrong_date
# 26481                          July 2006 &ndash;    wrong_date
# 26482                      November 2003 &ndash;    wrong_date
# 26558                        August 2011 &ndash;    wrong_date
# 26564                         April 2011 &ndash;    wrong_date
# 26693                           May 2007 &ndash;    wrong_date
# 26760                                        NaN    wrong_date
# 26945                     Meddius September 2009    wrong_date
# 27119                                        NaN    wrong_date
# 27444                                June 2009 –    wrong_date
# 27445                             January 2009 –    wrong_date
# 27734                                        NaN    wrong_date
# 27936                                   notKnown    wrong_date
# 27937                                   notKnown    wrong_date
# 28358                                   notKnown    wrong_date
# 28406                          July 2009 &ndash;    wrong_date
# 28506                                        NaN    wrong_date
# 28549                                        NaN    wrong_date
# 28607                                        NaN    wrong_date
# 28623                               2010 &ndash;    wrong_date
# 28630                     September 2007 &ndash;    wrong_date
# 28631                       October 2006 &ndash;    wrong_date
# 28632                          July 2005 &ndash;    wrong_date
# 28634                      November 2003 &ndash;    wrong_date
# 28635                          July 2003 &ndash;    wrong_date
# 28639                               2010 &ndash;    wrong_date
# 28646                     September 2007 &ndash;    wrong_date
# 28647                       October 2006 &ndash;    wrong_date
# 28648                          July 2005 &ndash;    wrong_date
# 28650                      November 2003 &ndash;    wrong_date
# 28651                          July 2003 &ndash;    wrong_date
# 28655                               2010 &ndash;    wrong_date
# 28662                     September 2007 &ndash;    wrong_date
# 28663                       October 2006 &ndash;    wrong_date
# 28664                          July 2005 &ndash;    wrong_date
# 28666                      November 2003 &ndash;    wrong_date
# 28667                          July 2003 &ndash;    wrong_date
# 28780                          July 2009 &ndash;    wrong_date
# 28781                         April 2009 &ndash;    wrong_date
# 28782                      February 2009 &ndash;    wrong_date
# 28784                      November 2008 &ndash;    wrong_date
# 28831                      December 2005 &ndash;    wrong_date
# 28832                       October 2003 &ndash;    wrong_date
# 28901                           Jul 2004 &ndash;    wrong_date
# 28911                           Oct 2011 &ndash;    wrong_date
# 28926                                        NaN    wrong_date
# 29162                     September 2007 &ndash;    wrong_date
# 29388                          June 2004 &ndash;    wrong_date
# 29684                                        NaN    wrong_date
# 29952              Sumitomo Bakelite (S) Pte Ltd    wrong_date
# 29986                             ptSeember 2008    wrong_date
# 30166                                        NaN    wrong_date
# 30766                                        NaN    wrong_date
# 30819                          July 2011 &ndash;    wrong_date
# 30825                       January 2005 &ndash;    wrong_date
# 30829                          July 2011 &ndash;    wrong_date
# 30835                       January 2005 &ndash;    wrong_date
# 30840                                        NaN    wrong_date
# 30935                                        NaN    wrong_date
# 30936                                      2009-    wrong_date
# 30947                      November 2011 &ndash;    wrong_date
# 30948                      November 2007 &ndash;    wrong_date
# 31003         January 1998 &ndash; December 1999    wrong_date
# 31023                                      1/03-    wrong_date
# 31024                                      2/09-    wrong_date
# 31025                                   5/2002 -    wrong_date
# 31027                                     11/08-    wrong_date
# 31036                                June 2007 -    wrong_date
# 31037                             January 2003 -    wrong_date
# 31221                       January 2005 &ndash;    wrong_date
# 31307                         April 2011 &ndash;    wrong_date
# 31308                          June 2010 &ndash;    wrong_date
# 31309                      February 2010 &ndash;    wrong_date
# 31310                      December 2008 &ndash;    wrong_date
# 31312                                 June 20076    wrong_date
# 31400                           Jan 2000 &ndash;    wrong_date
# 31408                         March 2010 &ndash;    wrong_date
# 31410                     September 2003 &ndash;    wrong_date
# 31433                           Feb 2005 &ndash;    wrong_date
# 31479                           May 2009 &ndash;    wrong_date
# 31485                                   notKnown    wrong_date
# 31593                                        207    wrong_date
# 31712                                   notKnown    wrong_date
# 31807                           May 2002 &ndash;    wrong_date
# 31889                                        NaN    wrong_date
# 32029                      December 2011 &ndash;    wrong_date
# 32031                      December 2011 &ndash;    wrong_date
# 32039                              December 00 -    wrong_date
# 32052                                 01/2010 to    wrong_date
# 32058                                 01/2010 to    wrong_date
# 32064                                 01/2010 to    wrong_date
# 32118                                June 2010 -    wrong_date
# 32143                                 1999 2004-    wrong_date
# 32347                                        NaN    wrong_date
# 32376                                         --    wrong_date
# 32428                           Aug 2011 &ndash;    wrong_date
# 32431                           Nov 2005 &ndash;    wrong_date
# 32480                           Apr 2012 &ndash;    wrong_date
# 32481                           Feb 2011 &ndash;    wrong_date
# 32485                           Jan 2007 &ndash;    wrong_date
# 32612                           May 2008 &ndash;    wrong_date
# 32613                           Dec 2006 &ndash;    wrong_date
# 32642                                    Technip    wrong_date
# 32657                          July 2008 &ndash;    wrong_date
# 32680                               2010 &ndash;    wrong_date
# 32705                          June 2011 &ndash;    wrong_date
# 32990                          July 2008 &ndash;    wrong_date
# 33061                             January 2012 -    wrong_date
# 33099                             October 2008 –    wrong_date
# 33101                              August 2007 –    wrong_date
# 33223                                   2009-090    wrong_date
# 33241                           May 2004 &ndash;    wrong_date
# 33242                     September 2001 &ndash;    wrong_date
# 33320                             October 2009 –    wrong_date
# 33321                                 May 2008 –    wrong_date
# 33322                               April 2004 –    wrong_date
# 33324         • Provide sales demos to potential    wrong_date
# 33325                           September 2011 –    wrong_date
# 33367                                 Jun 2007 -    wrong_date
# 33374                                     2009 -    wrong_date
# 33376                                     2008 -    wrong_date
# 33377                                     2007 -    wrong_date
# 33379                                      2005-    wrong_date
# 33381                                      2000-    wrong_date
# 33573                         March 2004 &ndash;    wrong_date
# 33637                       October 2010 &ndash;    wrong_date
# 33638                          June 2010 &ndash;    wrong_date
# 33639                         April 2009 &ndash;    wrong_date
# 34035                                        ---    wrong_date
# 34038                              September 201    wrong_date
# 34484                                    unknown    wrong_date
# 34523                                    unknown    wrong_date
# 34613                                        NaN    wrong_date
# 34623                                     2009 -    wrong_date
# 34624                              &bull; 2008 -    wrong_date
# 34625                                     2007 -    wrong_date
# 34629                                     2009 -    wrong_date
# 34630                              &bull; 2008 -    wrong_date
# 34631                                     2007 -    wrong_date
# 34645                                  Oct. 2001    wrong_date
# 34646                                  Aug. 2000    wrong_date
# 34748                                         --    wrong_date
# 34811                                        NaN    wrong_date
# 34846                                    unknown    wrong_date
# 34877                                   notKnown    wrong_date
# 34878                                    unknown    wrong_date
# 34932                                    unknown    wrong_date
# 35081                           Nov 2004 &ndash;    wrong_date
# ...
# 183036                                      Date    wrong_date
# 183057                                      Date    wrong_date
# 183197                            December, 2007    wrong_date
# 183279                                      date    wrong_date
# 183575                                       NaN    wrong_date
# 183588                                      Date    wrong_date
# 183659                                      Date    wrong_date
# 183834                                       NaN    wrong_date
# 183914                            - January 2008    wrong_date
# 183915                                       now    wrong_date
# 184123                             Jun 200505-12    wrong_date
# 184312                    &ndash; September 2002    wrong_date
# 184444                                      date    wrong_date
# 184502                                      date    wrong_date
# 184735                                       NaN    wrong_date
# 184759                              - April 2012    wrong_date
# 184772                                       NaN    wrong_date
# 184774                                       NaN    wrong_date
# 184841                                       NaN    wrong_date
# 184857                       2012-September 2010    wrong_date
# 185199                                  2012 -04    wrong_date
# 185209                                       NaN    wrong_date
# 185451                                  2008-015    wrong_date
# 185568                                       NaN    wrong_date
# 185598                          - September 2012    wrong_date
# 185602                                       NaN    wrong_date
# 185610                                    -01/13    wrong_date
# 185612                                    - 7/09    wrong_date
# 185920                                      Date    wrong_date
# 186205                                       NaN    wrong_date
# 186208                                       NaN    wrong_date
# 186287                                       Now    wrong_date
# 186352                                       now    wrong_date
# 186355                                       now    wrong_date
# 186500                                      date    wrong_date
# 186561                                      date    wrong_date
# 186801                                      Date    wrong_date
# 186804                                      Date    wrong_date
# 187142                                       now    wrong_date
# 187150                                       now    wrong_date
# 187394                                       now    wrong_date
# 187401                                       now    wrong_date
# 187408                                       now    wrong_date
# 187461                                       now    wrong_date
# 187466                                       now    wrong_date
# 187517                                       NaN    wrong_date
# 187534                           December 200-12    wrong_date
# 187758                              ebruary 2003    wrong_date
# 187769                                       NaN    wrong_date
# 187770                                       NaN    wrong_date
# 187771                                       NaN    wrong_date
# 187772                                       NaN    wrong_date
# 187866                                       now    wrong_date
# 188086                                       now    wrong_date
# 188095                                       now    wrong_date
# 188107                                       NaN    wrong_date
# 188115                                      Date    wrong_date
# 188201                                       NaN    wrong_date
# 188647                                       NaN    wrong_date
# 188648                                       NaN    wrong_date
# 188649                                       NaN    wrong_date
# 188650                                       NaN    wrong_date
# 188879                                June, 2007    wrong_date
# 189027                            - October 2012    wrong_date
# 189028                            - October 2012    wrong_date
# 189075                          8/2007 - 10/2008    wrong_date
# 189080                                  - 6/2001    wrong_date
# 189109                                       NaN    wrong_date
# 189111                                       NaN    wrong_date
# 189194                                       NaN    wrong_date
# 189206                                 Till date    wrong_date
# 189207                                - Jan 2012    wrong_date
# 189260                                       NaN    wrong_date
# 189492                                  8 / 2004    wrong_date
# 189502                                       Now    wrong_date
# 189592                                       NaN    wrong_date
# 189593                                       NaN    wrong_date
# 189788                                      date    wrong_date
# 189993                                       NaN    wrong_date
# 190286                            June 201212-06    wrong_date
# 190495                                       NaN    wrong_date
# 190496                                    - 2007    wrong_date
# 190497                                       NaN    wrong_date
# 190591                          to February 2004    wrong_date
# 190606                                       NaN    wrong_date
# 190657                                       NaN    wrong_date
# 190813                                       NaN    wrong_date
# 190933                                      Date    wrong_date
# 190934                                      Date    wrong_date
# 190961                                       NaN    wrong_date
# 191100                                       NaN    wrong_date
# 191146                      &ndash; October 2007    wrong_date
# 191246                                       NaN    wrong_date
# 191308                                       NaN    wrong_date
# 191475                                       NaN    wrong_date
# 191479                                       NaN    wrong_date
# 191491                               Augest 2003    wrong_date
# 191523                                     19998    wrong_date
# 191528                                       Now    wrong_date
# 191571                                      Date    wrong_date
# 191572                                      Date    wrong_date
# 191582                                       NaN    wrong_date
# 191603                                       NaN    wrong_date
# 191800                                       NaN    wrong_date
# 191819                                      Date    wrong_date
# 191905                                      Date    wrong_date
# 191906                                      Date    wrong_date
# 191940                                       now    wrong_date
# 192044                                       now    wrong_date
# 192049                                       now    wrong_date
# 192231                                      date    wrong_date
# 192264                                       NaN    wrong_date
# 192348                             eptember 2011    wrong_date
# 192368                                       NaN    wrong_date
# 192531                                       NaN    wrong_date
# 192667                                       NaN    wrong_date
# 192675                                      Date    wrong_date
# 192816                                      date    wrong_date
# 192871                                       Now    wrong_date
# 192914                                       Now    wrong_date
# 192923                                       Now    wrong_date
# 192932                                       Now    wrong_date
# 192980                                    resent    wrong_date
# 193053                                      date    wrong_date
# 193082                                       NaN    wrong_date
# 193409                             January 2009,    wrong_date
# 193457                                       NaN    wrong_date
# 193470                                       NaN    wrong_date
# 193556                           December 2002 (    wrong_date
# 193741                                       NaN    wrong_date
# 193743                                       NaN    wrong_date
# 193798                                       now    wrong_date
# 194129                                  2009 -10    wrong_date
# 194136                                  2009 -10    wrong_date
# 194143                                  2009 -10    wrong_date
# 194150                                  2009 -10    wrong_date
# 194454                                       Now    wrong_date
# 194628                                       NaN    wrong_date
# 194721                                       NaN    wrong_date
# 194829                                      Date    wrong_date
# 195331                                       now    wrong_date
# 195333                                      date    wrong_date
# 195379                                       now    wrong_date
# 195388                                 - Present    wrong_date
# 195557                                      date    wrong_date
# 195604                                June, 2004    wrong_date
# 195636                               - JULY 2005    wrong_date
# 196106                                      date    wrong_date
# 196125                     &ndash; November 2008    wrong_date
# 196135                                       NaN    wrong_date
# 196296                                       now    wrong_date
# 196624                                       NaN    wrong_date
# 196626                                       NaN    wrong_date
# 196627                                       NaN    wrong_date
# 196629                                       NaN    wrong_date
# 196739                                       NaN    wrong_date
# 196740                                       NaN    wrong_date
# 196961                                      date    wrong_date
# 197028                                       NaN    wrong_date
# 197050                                      date    wrong_date
# 197112                                       now    wrong_date
# 197370                                       now    wrong_date
# 197377                                       now    wrong_date
# 197434                                       NaN    wrong_date
# 197435                                       NaN    wrong_date
# 197436                                       NaN    wrong_date
# 197437                                       NaN    wrong_date
# 197438                                       NaN    wrong_date
# 197439                                       NaN    wrong_date
# 197440                                       NaN    wrong_date
# 197441                                       NaN    wrong_date
# 197458                                       NaN    wrong_date
# 197462                                       NaN    wrong_date
# 197466                                 - 08/2001    wrong_date
# 197467                                 - 05/1997    wrong_date
# 197490                                       NaN    wrong_date
# 197494                                       NaN    wrong_date
# 197531                           December 2009 (    wrong_date
# 197532                         &ndash; July 2007    wrong_date
# 197562                                      Date    wrong_date
# 197563                                      Date    wrong_date
# 197564                                      Date    wrong_date
# 197937                                       now    wrong_date
# 197943                                       now    wrong_date
# 197949                                       now    wrong_date
# 197978                            March &#039;12    wrong_date
# 197979                            April &#039;13    wrong_date
# 197980                                        09    wrong_date
# 198416                                       NaN    wrong_date
# 198420                                       NaN    wrong_date
# 198498                                      date    wrong_date
# 198767                                       now    wrong_date
# 198923                                       NaN    wrong_date
# 198986                                May 2009 (    wrong_date
# 199186                              &ndash; 2006    wrong_date
# 199288                                   Jan2013    wrong_date
# 199290                                       NaN    wrong_date
# 199325                                       NaN    wrong_date
# 199335                              July 2013 (4    wrong_date
# 199520                     &ndash; November 2012    wrong_date
# 199729                      &ndash; January 2013    wrong_date
# 199735                      &ndash; January 2013    wrong_date
# 199741                      &ndash; January 2013    wrong_date
# 199747                      &ndash; January 2013    wrong_date
# 199753                      &ndash; January 2013    wrong_date
# 199804                      &ndash; January 2008    wrong_date
# 199871                          &ndash; Jun 2004    wrong_date
